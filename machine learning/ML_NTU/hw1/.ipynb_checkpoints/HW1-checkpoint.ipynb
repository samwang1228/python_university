# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# # 自定義屬性

# %%
train_data = pd.read_csv('train.csv',encoding = 'big5')
test_data = pd.read_csv('test.csv',encoding = 'big5',names = ['id', '測項', '0', '1', '2', '3', '4', '5', '6', '7', '8'])
test_data['id'] = test_data['id'].str.split('_',expand = True)[1].astype('int')
test_data
# Out:
#        id          測項     0     1     2     3     4     5     6     7     8
# 0       0    AMB_TEMP    21    21    20    20    19    19    19    18    17
# 1       0         CH4   1.7   1.7   1.7   1.7   1.7   1.7   1.7   1.7   1.8
# 2       0          CO  0.39  0.36  0.36   0.4  0.53  0.55  0.34  0.31  0.23
# 3       0        NMHC  0.16  0.24  0.22  0.27  0.27  0.26  0.27  0.29   0.1
# 4       0          NO   1.3   1.3   1.3   1.3   1.4   1.6   1.2   1.1   0.9
# ...   ...         ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 4315  239         THC   1.8   1.8   1.8   1.8   1.7   1.7   1.7   1.7   1.7
# 4316  239       WD_HR    80    92    95    95    96    97    96    96    84
# 4317  239  WIND_DIREC    76    99    93    97    93    94    98    97    65
# 4318  239  WIND_SPEED   2.2   3.2   2.5   3.6     5   4.2   5.7   4.9   3.6
# 4319  239       WS_HR   1.7   2.8   2.6   3.3   3.5     5   4.9   5.2   3.6
#
# [4320 rows x 11 columns]

# %% [markdown]
# #  RAINFALL為是否下雨 NR為沒下雨因此將NR-->0

# %%
#看看RAINFALL
rainfall = train_data[train_data['測項'].isin(['RAINFALL'])]
# inplace=true 直接對data做修改 =false創建一個新的dataframe(修改前的還在)
train_data.replace("NR",0, inplace = True)
test_data.replace("NR",0, inplace = True)
train_data.head(18)
rainfall = train_data[train_data['測項'].isin(['RAINFALL'])]
#rainfall.info()
#
for num in range(0,23) :
    num = str(num)
    train_data[num] = train_data[num].astype(float)

train_data.head()
#先置换一下行和列
#train_data_reshaped = train_data.pivot_table(train_data,index=[u'0'],columns="測項")
#train_data_reshaped.head()
#columns=('idx','degree','weight','diameter')
train_data_re = pd.DataFrame()
for num in range(24):
    num = str(num)
    train_data_re = train_data_re.append(
                pd.DataFrame(train_data[num].values.reshape(1,-1), 
                index=['id_'+num], 
                columns=train_data['測項'].values)
                )
train_data_re.head(25)

#把无用数据删掉
train_data.head()
train_data_v2 = train_data.copy()
#删掉了测站
train_data_v2 = train_data_v2.drop(columns = '測站')
train_data_v2
# 日期	測項	0	1
# Out:
#               日期          測項      0      1      2       3      4      5  \
# 0       2014/1/1    AMB_TEMP  14.00  14.00  14.00   13.00  12.00  12.00
# 1       2014/1/1         CH4   1.80   1.80   1.80    1.80   1.80   1.80
# 2       2014/1/1          CO   0.51   0.41   0.39    0.37   0.35   0.30
# 3       2014/1/1        NMHC   0.20   0.15   0.13    0.12   0.11   0.06
# 4       2014/1/1          NO   0.90   0.60   0.50    1.70   1.80   1.50
# ...          ...         ...    ...    ...    ...     ...    ...    ...
# 4315  2014/12/20         THC   1.80   1.80   1.80    1.80   1.80   1.70
# 4316  2014/12/20       WD_HR  46.00  13.00  61.00   44.00  55.00  68.00
# 4317  2014/12/20  WIND_DIREC  36.00  55.00  72.00  327.00  74.00  52.00
# 4318  2014/12/20  WIND_SPEED   1.90   2.40   1.90    2.80   2.30   1.90
# 4319  2014/12/20       WS_HR   0.70   0.80   1.80    1.00   1.90   1.70
#
#           6      7  ...     14      15      16     17      18      19      20  \
# 0     12.00  12.00  ...  22.00   22.00   21.00  19.00   17.00   16.00   15.00
# 1      1.80   1.80  ...   1.80    1.80    1.80   1.80    1.80    1.80    1.80
# 2      0.37   0.47  ...   0.37    0.37    0.47   0.69    0.56    0.45    0.38
# 3      0.10   0.13  ...   0.10    0.13    0.14   0.23    0.18    0.12    0.10
# 4      1.90   2.20  ...   2.50    2.20    2.50   2.30    2.10    1.90    1.50
# ...     ...    ...  ...    ...     ...     ...    ...     ...     ...     ...
# 4315   1.70   1.80  ...   1.80    1.80    2.00   2.10    2.00    1.90    1.90
# 4316  66.00  70.00  ...  59.00  308.00  327.00  21.00  100.00  109.00  108.00
# 4317  59.00  83.00  ...  18.00  311.00   52.00  54.00  121.00   97.00  107.00
# 4318   2.10   3.70  ...   2.30    2.60    1.30   1.00    1.50    1.00    1.70
# 4319   2.10   2.00  ...   1.30    1.70    0.70   0.40    1.10    1.40    1.30
#
#           21      22    23
# 0      15.00   15.00    15
# 1       1.80    1.80   1.8
# 2       0.35    0.36  0.32
# 3       0.09    0.10  0.08
# 4       1.60    1.80   1.5
# ...      ...     ...   ...
# 4315    1.90    2.00     2
# 4316  114.00  108.00   109
# 4317  118.00  100.00   105
# 4318    1.50    2.00     2
# 4319    1.60    1.80     2
#
# [4320 rows x 26 columns]

# %%
# train_data_v2

train_data_new = pd.DataFrame()
for x in range(24):
    train_data_first = train_data_v2[['日期','測項',str(x)]].copy()
    train_data_first['日期'] = pd.to_datetime(train_data_first['日期']+' '+str(x)+':00:00') #將col 0 1...23轉為時間排序
    train_data_first = train_data_first.pivot(index = '日期',columns = '測項', values = str(x)) #用日期做index col改為選項依序放入data
    train_data_new = pd.concat([train_data_new,train_data_first]) #每次的first為一個row合併治new
train_data_new = train_data_new.astype('float64').sort_index().reset_index().drop(['日期'], axis = 1) 
#axis 
# 1:delete col 屬性 
# 0:delete row 測資
train_data_new
# Out:
# 測項    AMB_TEMP  CH4    CO  NMHC   NO   NO2   NOx    O3  PM10  PM2.5  RAINFALL  \
# 0         14.0  1.8  0.51  0.20  0.9  16.0  17.0  16.0  56.0   26.0       0.0
# 1         14.0  1.8  0.41  0.15  0.6   9.2   9.8  30.0  50.0   39.0       0.0
# 2         14.0  1.8  0.39  0.13  0.5   8.2   8.7  27.0  48.0   36.0       0.0
# 3         13.0  1.8  0.37  0.12  1.7   6.9   8.6  23.0  35.0   35.0       0.0
# 4         12.0  1.8  0.35  0.11  1.8   6.8   8.5  24.0  25.0   31.0       0.0
# ...        ...  ...   ...   ...  ...   ...   ...   ...   ...    ...       ...
# 5755      14.0  1.8  0.48  0.15  1.0  13.0  14.0  18.0  54.0   37.0       0.0
# 5756      13.0  1.8  0.47  0.16  1.5  13.0  15.0  14.0  66.0   28.0       0.0
# 5757      13.0  1.8  0.51  0.16  1.5  13.0  15.0  13.0  50.0   17.0       0.0
# 5758      13.0  1.8  0.57  0.19  1.1  13.0  14.0  13.0  32.0   24.0       0.0
# 5759      13.0  1.8  0.56  0.19  1.3  14.0  15.0  13.0  22.0   29.0       0.0
#
# 測項      RH  SO2  THC  WD_HR  WIND_DIREC  WIND_SPEED  WS_HR
# 0     77.0  1.8  2.0   37.0        35.0         1.4    0.5
# 1     68.0  2.0  2.0   80.0        79.0         1.8    0.9
# 2     67.0  1.7  2.0   57.0         2.4         1.0    0.6
# 3     74.0  1.6  1.9   76.0        55.0         0.6    0.3
# 4     72.0  1.9  1.9  110.0        94.0         1.7    0.6
# ...    ...  ...  ...    ...         ...         ...    ...
# 5755  76.0  2.6  1.9  109.0        97.0         1.0    1.4
# 5756  80.0  2.2  1.9  108.0       107.0         1.7    1.3
# 5757  82.0  2.3  1.9  114.0       118.0         1.5    1.6
# 5758  84.0  2.3  2.0  108.0       100.0         2.0    1.8
# 5759  84.0  2.3  2.0  109.0       105.0         2.0    2.0
#
# [5760 rows x 18 columns]

# %% [markdown]
# # feature scaling for train_data (x-μ)/σ

# %%
μ=train_data_new.mean().copy()
σ=train_data_new.std().copy()
for col in train_data_new:
#     print(col)
    train_data_new[col]=(train_data_new[col]-μ[col])/σ[col]
train_data_new
# Out:
# 測項    AMB_TEMP       CH4        CO      NMHC        NO       NO2       NOx  \
# 0    -1.355677  0.779179  0.375919  0.569287 -0.541475  0.949327  0.627186
# 1    -1.355677  0.779179  0.066870  0.091480 -0.672929 -0.149654 -0.323041
# 2    -1.355677  0.779179  0.005060 -0.099643 -0.716748 -0.311268 -0.468215
# 3    -1.514655  0.779179 -0.056750 -0.195204 -0.190929 -0.521367 -0.481412
# 4    -1.673634  0.779179 -0.118560 -0.290765 -0.147111 -0.537529 -0.494610
# ...        ...       ...       ...       ...       ...       ...       ...
# 5755 -1.355677  0.779179  0.283204  0.091480 -0.497656  0.464482  0.231258
# 5756 -1.514655  0.779179  0.252299  0.187041 -0.278565  0.464482  0.363234
# 5757 -1.514655  0.779179  0.375919  0.187041 -0.278565  0.464482  0.363234
# 5758 -1.514655  0.779179  0.561349  0.473725 -0.453838  0.464482  0.231258
# 5759 -1.514655  0.779179  0.530444  0.473725 -0.366202  0.626097  0.363234
#
# 測項          O3      PM10     PM2.5  RAINFALL        RH       SO2       THC  \
# 0    -0.850401  0.506851  0.275214 -0.098084  0.282219 -0.530081  0.881810
# 1    -0.101878  0.278038  1.055407 -0.098084 -0.391365 -0.420006  0.881810
# 2    -0.262276  0.201767  0.875363 -0.098084 -0.466208 -0.585118  0.881810
# 3    -0.476140 -0.293994  0.815348 -0.098084  0.057691 -0.640156  0.331872
# 4    -0.422674 -0.675349  0.575288 -0.098084 -0.091994 -0.475043  0.331872
# ...        ...       ...       ...       ...       ...       ...       ...
# 5755 -0.743469  0.430580  0.935378 -0.098084  0.207377 -0.089780  0.331872
# 5756 -0.957333  0.888206  0.395244 -0.098084  0.506748 -0.309930  0.331872
# 5757 -1.010799  0.278038 -0.264920 -0.098084  0.656433 -0.254893  0.331872
# 5758 -1.010799 -0.408401  0.155184 -0.098084  0.806119 -0.254893  0.881810
# 5759 -1.010799 -0.789756  0.455259 -0.098084  0.806119 -0.254893  0.881810
#
# 測項       WD_HR  WIND_DIREC  WIND_SPEED     WS_HR
# 0    -1.246312   -1.303972   -0.842156 -1.141225
# 1    -0.797207   -0.839334   -0.466713 -0.764819
# 2    -1.037426   -1.648226   -1.217599 -1.047123
# 3    -0.838984   -1.092773   -1.593042 -1.329428
# 4    -0.483877   -0.680935   -0.560574 -1.047123
# ...        ...         ...         ...       ...
# 5755 -0.494322   -0.649255   -1.217599 -0.294312
# 5756 -0.504766   -0.543656   -0.560574 -0.388413
# 5757 -0.442100   -0.427496   -0.748295 -0.106109
# 5758 -0.504766   -0.617575   -0.278991  0.082094
# 5759 -0.494322   -0.564776   -0.278991  0.270297
#
# [5760 rows x 18 columns]

# %% [markdown]
# # PM2.5的測資不需要scaling

# %%
tx = train_data_new.copy()
tx.columns = tx.columns + '_0'
for i in range(1,10):
    ty = train_data_new.copy()
    if i == 9:
        ty = ty[['PM2.5']]
        #將結果放大回去(PM2.5)
        ty = ty * σ['PM2.5'] + μ['PM2.5']
    ty.columns = ty.columns + '_' + str(i)
    for j in range(i):
        ty = ty.drop([j])
    tx = pd.concat([tx, ty.reset_index().drop(['index'], axis=1)], axis=1)
#看不懂
for i in range(12):
    for j in range(9):
        tx = tx.drop([480*(i+1)-9+j])
train_data = tx
train_data.describe()
# Out:
# 測項      AMB_TEMP_0        CH4_0         CO_0       NMHC_0         NO_0  \
# count  5652.000000  5652.000000  5652.000000  5652.000000  5652.000000
# mean      0.001447    -0.000058     0.002074    -0.002610     0.005129
# std       0.999257     1.004981     1.008012     0.998278     1.006198
# min      -5.536816   -15.186918    -1.571093    -1.341940    -1.417839
# 25%      -0.719762    -0.817431    -0.427610    -0.673011    -0.453838
# 50%       0.075131    -0.019126    -0.149465    -0.290765    -0.234747
# 75%       0.711046     0.779179     0.190489     0.378164     0.071981
# max       2.141854     2.375788    22.194821    11.081035    12.647813
#
# 測項           NO2_0        NOx_0         O3_0       PM10_0      PM2.5_0  ...  \
# count  5652.000000  5652.000000  5652.000000  5652.000000  5652.000000  ...
# mean     -0.001535     0.000253    -0.000522    -0.004793    -0.004590  ...
# std       1.002372     1.003812     1.003651     1.002963     1.003339  ...
# min      -1.636509    -1.933149    -1.705857    -1.628736    -1.345187  ...
# 25%      -0.682982    -0.652981    -0.743469    -0.713485    -0.745039  ...
# 50%      -0.246622    -0.296646    -0.155344    -0.179588    -0.204905  ...
# 75%       0.464482     0.363234     0.539714     0.506851     0.455259  ...
# max       5.797768     7.753892    10.644782     5.273788     5.436493  ...
#
# 測項         PM2.5_8   RAINFALL_8         RH_8        SO2_8        THC_8  \
# count  5652.000000  5652.000000  5652.000000  5652.000000  5652.000000
# mean     -0.002562     0.000750    -0.013894     0.005757    -0.000990
# std       0.997342     1.008693     0.999491     1.005869     1.003396
# min      -1.345187    -0.098084    -3.310232    -2.401358   -11.216819
# 25%      -0.745039    -0.098084    -0.690736    -0.640156    -0.768003
# 50%      -0.204905    -0.098084     0.132534    -0.254893    -0.218066
# 75%       0.455259    -0.098084     0.806119     0.350521     0.331872
# max       5.436493    36.079898     1.928760    10.587510     6.381187
#
# 測項         WD_HR_8  WIND_DIREC_8  WIND_SPEED_8      WS_HR_8      PM2.5_9
# count  5652.000000   5652.000000   5652.000000  5652.000000  5652.000000
# mean      0.004713      0.005549      0.008337     0.003826    21.374027
# std       1.003836      1.003166      1.001812     1.003796    16.614767
# min      -1.631707     -1.673570     -2.156207    -1.611732    -1.000000
# 25%      -0.880761     -0.871014     -0.748295    -0.764819     9.000000
# 50%      -0.389879     -0.385256     -0.185131    -0.200211    18.000000
# 75%       0.602331      0.652259      0.565756     0.552601    29.250000
# max       2.127201      2.128011      5.071072     4.975368   112.000000
#
# [8 rows x 163 columns]

# %% [markdown]
# # 這裡在做之前train data做的事只是test data再做一次

# %%
# iloc[:,[x]] 去得所有x行的測資
test_data_new = pd.DataFrame()
for i in range(9): #col數(上到下)
    test_data_slice = test_data[['id', '測項', str(i)]].copy()
    test_data_slice = test_data_slice.pivot(index='id', columns='測項', values=str(i))
    test_data_slice.columns = test_data_slice.columns + '_' + str(i)
    for j in range(18): #18個測項
        test_data_slice.iloc[:,[j]] = (test_data_slice.iloc[:,[j]].replace('NR', '0').astype('float64') - μ[j]) / σ[j]
    test_data_new = pd.concat([test_data_new, test_data_slice], axis=1)

test_data_new = test_data_new.replace('NR', '0').astype('float64').reset_index().drop(['id'], axis=1)
test_data_new
# Out:
# 測項   AMB_TEMP_0     CH4_0      CO_0    NMHC_0      NO_0     NO2_0     NOx_0  \
# 0     -0.242826 -0.019126  0.005060  0.187041 -0.366202  1.110941  0.759162
# 1     -1.355677  0.779179 -0.180370 -0.004081 -0.629111 -0.020362 -0.164670
# 2      1.505939  0.779179  0.994018  1.524900 -0.497656  0.949327  0.627186
# 3     -1.037719  0.779179  1.179448  2.002707  0.203435  4.828080  4.058563
# 4      0.234110 -0.019126 -0.334895 -0.290765 -0.366202 -0.068846 -0.164670
# ..          ...       ...       ...       ...       ...       ...       ...
# 235    0.075131  1.577484  0.715874  1.047094  0.115799  0.787712  0.627186
# 236    0.393089 -0.019126  0.406824  0.760410  0.159617  1.110941  1.023114
# 237    0.393089  0.779179  0.684969  0.187041 -0.322384  0.787712  0.495210
# 238   -1.832613 -0.019126 -0.211275 -0.577449 -0.278565 -0.796112 -0.732167
# 239   -1.355677 -0.019126 -0.365800 -0.481888 -0.585293 -0.521367 -0.613388
#
# 測項       O3_0    PM10_0   PM2.5_0  ...    PM10_8   PM2.5_8  RAINFALL_8  \
# 0    0.005054  0.735664  0.695318  ... -0.675349 -1.045113   -0.098084
# 1   -0.422674 -0.255859 -0.264920  ... -0.370265 -0.204905   -0.098084
# 2    3.640740  2.413626  1.715571  ...  1.269561  0.275214   -0.098084
# 3   -0.690003  5.083110  3.816091  ... -1.209246 -1.045113   -0.098084
# 4   -1.299515  0.125496 -0.264920  ...  1.193290  0.515273   -0.098084
# ..        ...       ...       ...  ...       ...       ...         ...
# 235 -1.395754  2.451761  2.495764  ...  0.583122  1.775586   -0.098084
# 236  2.731819  2.833116  1.655556  ...  1.956000  3.215943   -0.098084
# 237 -0.208810  1.574645  2.255705  ...  1.193290  1.055407   -0.098084
# 238 -1.010799 -1.094840 -0.564994  ... -0.637214 -1.285173   -0.098084
# 239  1.288237 -0.827891  0.035155  ... -1.399923 -0.324935   -0.098084
#
# 測項       RH_8     SO2_8     THC_8   WD_HR_8  WIND_DIREC_8  WIND_SPEED_8  \
# 0    0.506748 -0.199855  0.331872 -0.546543     -0.585895      0.002591
# 1   -0.017151 -0.640156  0.331872 -0.650986     -0.659815     -0.842156
# 2   -0.017151  0.295483 -0.218066 -1.047870     -1.272292     -1.405321
# 3   -0.541051 -0.860306 -0.218066 -0.577876     -0.226857     -0.936017
# 4   -0.840422  0.845859 -0.768003  1.510986      1.462735      0.284173
# ..        ...       ...       ...       ...           ...           ...
# 235  1.180332  0.075333 -0.218066 -0.995649     -1.187813     -0.936017
# 236  0.955804 -0.585118  0.331872 -0.462989     -0.511976     -0.185131
# 237 -1.813377  0.130370 -0.218066  1.604985      1.452175      0.941199
# 238 -1.738534  2.992324  3.631498  1.040992      1.156496     -1.029877
# 239 -2.636647 -0.585118 -0.768003 -0.755430     -0.987173      1.222781
#
# 測項    WS_HR_8
# 0    0.082094
# 1   -0.482515
# 2   -0.576616
# 3   -0.482515
# 4    0.552601
# ..        ...
# 235 -1.141225
# 236  0.176195
# 237  1.211311
# 238 -1.141225
# 239  1.775919
#
# [240 rows x 162 columns]

# %% [markdown]
# # 接下來開始看不懂QAQ

# %%
train_x = train_data.drop(['PM2.5_9'],axis = 1)
train_y = train_data[['PM2.5_9']]
# arr1 = np.array([1, 2, 3])
# arr2 = np.array([4, 5, 6])
# res = np.hstack((arr1, arr2))

# print res ->[1 2 3 4 5 6]
x = np.hstack((train_x.values,np.ones((np.size(train_x.values,0),1),'double'))) 
y = train_y.values
x,y
# Out:
# (array([[-1.35567676,  0.77917878,  0.37591913, ..., -1.59304207,
#          -1.1412249 ,  1.        ],
#         [-1.35567676,  0.77917878,  0.06686953, ..., -1.40532054,
#          -1.32942776,  1.        ],
#         [-1.35567676,  0.77917878,  0.00505961, ..., -0.65443441,
#          -0.85892061,  1.        ],
#         ...,
#         [-0.87874077, -0.01912605, -0.45851479, ..., -0.56057365,
#          -0.38841346,  1.        ],
#         [-0.7197621 , -0.01912605, -0.48941975, ..., -0.74829518,
#          -0.10610916,  1.        ],
#         [-0.56078344, -0.01912605, -0.45851479, ..., -0.27899135,
#           0.0820937 ,  1.        ]]),
#  array([[30.],
#         [41.],
#         [44.],
#         ...,
#         [17.],
#         [24.],
#         [29.]]))

# %%
# 预测方法
# LOSS function
def loss(x,y,data):
    return np.sum((y- x @ data)**2)

# 梯度下降
def gradientDescent(x,y,data):
    return ((train_x_x) @ data) - (train_x_y) +(1 * data)

# %%
# np.size(x,y) 如果传入的参数只有一个，则返回矩阵的元素个数 如果传入的第二个参数是0，则返回矩阵的行数 如果传入的第二个参数是1，则返回矩阵的列数

data = np.random.random((np.size(x,1),1))
data
#学习速率
learning_rate = 0.00000006
regular_one = 1

#把训练数据分成四份 按照3:1的比例设置为 训练集和验证集
train_X = x[:4320]
train_Y = y[:4320]
vari_X = x[4320:]
vari_Y = y[4320:]

#GD =  gradientDescent(train_X,train_Y,data)
#把gradientdescent里的参数提取出来 这样就不用在迭代过程中反复计算 可以节约时间
train_x_x = train_X.T @ train_X
train_x_y = train_X.T @ train_Y

for i in range(2000001):
    data = data - learning_rate * gradientDescent(train_X,train_Y,data)
    if i %50000 == 0 :
        #输出训练集误差和验证集误差 
        print(i,loss(train_X,train_Y,data) / np.size(train_Y,0) , loss(vari_X,vari_Y,data) / np.size(train_Y,0))


print(np.size(data,0), np.size(data,1))
# Out:
# 0 749.9264713909098 347.83711492958753
# 50000 37.079139468360545 11.01701372124748
# 100000 34.978917822630024 10.101453215398468
# 150000 34.17421146290977 9.793331793566532
# 200000 33.77073233589639 9.662570641116915
# 250000 33.54904352842287 9.60282056234917
# 300000 33.42168979487469 9.57565018032049
# 350000 33.34627671375018 9.56425642679397
# 400000 33.300380157348144 9.560541138483892
# 450000 33.271610996265764 9.560422861609721
# 500000 33.25295120607599 9.561822006326821
# 550000 33.240358642359226 9.563696754648788
# 600000 33.231474747579774 9.565550877750525
# 650000 33.22490694956342 9.567173347698368
# 700000 33.2198229190938 9.56849842696365
# 750000 33.215718314147246 9.569530460934871
# 800000 33.212282591031595 9.570303980041679
# 850000 33.20932086371605 9.570863145744662
# 900000 33.20670806133077 9.571251728790763
# 950000 33.20436182471002 9.571508728061254
# 1000000 33.20222634307371 9.571666919861094
# 1050000 33.20026261793554 9.57175285001914
# 1100000 33.19844252871717 9.571787466654746
# 1150000 33.19674516455706 9.571786973944235
# 1200000 33.195154519304545 9.571763698364927
# 1250000 33.19365801537098 9.571726873362845
# 1300000 33.19224553800657 9.571683308653627
# 1350000 33.19090878863722 9.57163794057222
# 1400000 33.18964084110689 9.571594273725621
# 1450000 33.188435829487716 9.571554729366026
# 1500000 33.18728872303661 9.5715209166927
# 1550000 33.186195160193286 9.571493842033096
# 1600000 33.185151323516635 9.571474068815752
# 1650000 33.184153843665776 9.571461839051713
# 1700000 33.18319972444613 9.57145716499474
# 1750000 33.18228628344832 9.571459897871348
# 1800000 33.18141110444531 9.571469779088696
# 1850000 33.180571998803174 9.571486478122935
# 1900000 33.17976697390155 9.571509620331087
# 1950000 33.178994207074474 9.571538807173622
# 2000000 33.17825202394539 9.571573630746382
# 163 1

# %%
test_x = np.hstack((test_data_new.values, np.ones((np.size(test_data_new.values,0), 1), 'double')))
print(np.size(test_x,0), np.size(test_x,1))

test_y = test_x @ (data)
test_y
# Out:
# 240 163
# array([[  7.10080352],
#        [ 18.30992418],
#        [ 24.78282229],
#        [  6.90998026],
#        [ 27.35715939],
#        [ 22.44135178],
#        [ 24.31810168],
#        [ 31.12209851],
#        [ 16.81840748],
#        [ 60.28353424],
#        [ 12.03540114],
#        [  8.91280577],
#        [ 63.17972713],
#        [ 53.74748238],
#        [ 21.95460678],
#        [ 12.23581183],
#        [ 32.25580579],
#        [ 65.88864047],
#        [ -1.25328908],
#        [ 17.0553479 ],
#        [ 41.6297979 ],
#        [ 71.78327689],
#        [  8.79018695],
#        [ 17.81074535],
#        [ 14.94283853],
#        [ 38.55065847],
#        [ 14.46892126],
#        [ 69.06254553],
#        [  6.87356243],
#        [ 55.95905413],
#        [ 24.37172385],
#        [  9.27578165],
#        [  3.50797299],
#        [ 18.66202393],
#        [ 28.62151993],
#        [ 37.30609928],
#        [ 43.15430862],
#        [ 30.47268104],
#        [ 41.30187214],
#        [ 35.63041128],
#        [  7.13004649],
#        [ 41.5160245 ],
#        [ 30.83291533],
#        [ 51.56886341],
#        [ 18.12546063],
#        [ 35.62223408],
#        [ 24.14272771],
#        [  8.93911027],
#        [ 26.38220902],
#        [ 32.56336353],
#        [ 20.78863583],
#        [  7.95476242],
#        [ 22.07124134],
#        [ 52.78232146],
#        [ 16.6171339 ],
#        [ 36.12342793],
#        [ 32.36352505],
#        [ 20.7299043 ],
#        [ 57.95848307],
#        [ 22.85019556],
#        [ 14.75084569],
#        [ 41.71984361],
#        [ 12.72127473],
#        [ 48.73333831],
#        [ 13.22177791],
#        [ 14.95150059],
#        [ 14.81074599],
#        [ -1.67572649],
#        [ 44.14769704],
#        [ 30.15762864],
#        [ 19.82554377],
#        [ 41.13252002],
#        [ 60.44181225],
#        [  5.84200419],
#        [ 16.42299646],
#        [  3.83257354],
#        [ 40.49142987],
#        [ 14.7841283 ],
#        [ 22.44486281],
#        [ 20.8713092 ],
#        [ 23.98848715],
#        [ 36.16012767],
#        [ 22.39412427],
#        [ 90.47439918],
#        [ 37.81228707],
#        [ 29.51623541],
#        [ 22.51547277],
#        [ 33.22434993],
#        [ 24.12481085],
#        [ 19.77759427],
#        [ 28.96254175],
#        [ 41.6442509 ],
#        [  4.78576065],
#        [ 38.44622841],
#        [ 46.04760154],
#        [ 16.42951171],
#        [ 32.23063962],
#        [ 13.13710758],
#        [ 23.55198371],
#        [  5.63835999],
#        [ 18.47789942],
#        [ 27.17736819],
#        [ 13.36234411],
#        [ 16.56179307],
#        [ 25.65940966],
#        [ 39.47691448],
#        [ 32.2797431 ],
#        [  6.58416941],
#        [  6.13646369],
#        [ 77.95377702],
#        [ 47.19346056],
#        [ 17.3090896 ],
#        [ 28.55443919],
#        [ 16.04819059],
#        [ 14.22707618],
#        [ 25.01961283],
#        [ 26.52371911],
#        [ 11.07263446],
#        [ 18.31151077],
#        [ 19.34268201],
#        [ 81.47106908],
#        [ 25.67730981],
#        [ 36.53054368],
#        [ 25.62180704],
#        [  7.20155285],
#        [ 38.68708808],
#        [  9.68211668],
#        [ 21.58757555],
#        [ 29.3587029 ],
#        [ 63.17913843],
#        [ 22.79045714],
#        [ 23.18013608],
#        [ 59.45545486],
#        [ 14.9801043 ],
#        [ 13.86607527],
#        [  3.73388614],
#        [ 12.50170175],
#        [ 58.42950378],
#        [ 19.59681495],
#        [  4.90992284],
#        [ 28.66733637],
#        [ 24.8427438 ],
#        [ 44.15165495],
#        [ 31.14465621],
#        [ 17.41602783],
#        [ 25.95896443],
#        [ 12.32128245],
#        [ 51.7512999 ],
#        [ 23.00474235],
#        [ 38.96931833],
#        [ 10.66181319],
#        [  8.46005295],
#        [ 24.18417418],
#        [  6.44177312],
#        [ 15.79384758],
#        [ 40.89078991],
#        [  8.18280302],
#        [ 35.70569219],
#        [ 12.22565848],
#        [ 19.61307245],
#        [ 41.78261137],
#        [ 20.33212541],
#        [ 13.51226829],
#        [  8.04296208],
#        [ 54.46737642],
#        [ 31.06329296],
#        [ -0.82137405],
#        [ 17.45887397],
#        [ 63.9541522 ],
#        [ 13.56427827],
#        [ 64.47254302],
#        [ 39.67999887],
#        [ 26.57112573],
#        [ 20.39424569],
#        [ 61.63605189],
#        [ 24.35109009],
#        [ 20.7461138 ],
#        [ 37.55448249],
#        [ 12.6430096 ],
#        [ 30.93078416],
#        [ 17.13012789],
#        [ 11.3318663 ],
#        [ 55.67555837],
#        [ 46.40842102],
#        [ 16.33081499],
#        [ 34.40280685],
#        [ 26.30786239],
#        [ 69.05330493],
#        [ 10.29783558],
#        [ 59.19769056],
#        [ 37.7116724 ],
#        [ 14.45868753],
#        [ 29.07225757],
#        [ -0.99536821],
#        [ 19.2632124 ],
#        [  1.28565234],
#        [ 33.79375211],
#        [ 10.88900733],
#        [ 19.01953779],
#        [ 60.87168307],
#        [ 25.54694989],
#        [ 26.08170649],
#        [ 64.58541643],
#        [ 10.92666029],
#        [ 10.03526422],
#        [ 11.63523995],
#        [  6.89439664],
#        [  1.90762748],
#        [123.042434  ],
#        [ 20.37428332],
#        [ 16.02045744],
#        [ 13.80762865],
#        [ 35.74293949],
#        [ 35.94410847],
#        [ 19.31805188],
#        [ 35.09948268],
#        [ 78.57663254],
#        [  0.58864232],
#        [ 13.08006803],
#        [ 32.18714545],
#        [ 15.53551496],
#        [ 13.0463256 ],
#        [113.36553123],
#        [ 12.95047955],
#        [ 17.20746823],
#        [ 64.10727141],
#        [ 15.49950331],
#        [ 18.8581741 ],
#        [ 10.82258231],
#        [  5.91603756],
#        [ 45.84378757],
#        [ 13.33536787],
#        [ 52.50036219],
#        [ 43.74581481],
#        [ 25.73241102],
#        [ 41.06869742],
#        [ 68.70750868],
#        [ 41.48998379],
#        [ 11.77181954],
#        [ 18.7706615 ]])

# %% [markdown]
# # 將data放入csv

# %%
test_data_id = test_data['id']

submission = pd.DataFrame({
        "id": test_data_id.unique(),
        "value": test_y.T[0]
    })
submission.to_csv('submission.csv', index=False)
