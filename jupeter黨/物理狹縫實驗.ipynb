# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 讀取圖檔
img = cv2.imread("s.jpg") #將sample.jpg跟python檔放在同一個資料夾
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) #convert it to hsv


l1=hsv[...,2][1105] #230 y
l2=hsv[...,2][1115] #230
l3=hsv[...,2][1120] #230

l4 = np.add(l1,l3)
l5 = np.add(l4,l2)
#print(x)

np.savetxt("C:\\bbb\\1.csv", l1, delimiter=",")
np.savetxt("C:\\bbb\\2.csv", l2, delimiter=",")
np.savetxt("C:\\bbb\\3.csv", l3, delimiter=",")

plt.plot(np.arange(len(l1)),l1,color='red',linewidth=1,ls=":")
plt.plot(np.arange(len(l2)),l2,color='green',linewidth=1,ls=":")
plt.plot(np.arange(len(l3)),l3,color='blue',linewidth=1,ls=":")
plt.xlim(500,2500)#x間距
#plt.ylim(150,270)
plt.show()


plt.plot(np.arange(len(l5)),l5,color='red',linewidth=1,ls=":")
plt.show()

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.xlim(0,4000)
plt.plot([500,2500],[1125,1125])#x y
plt.plot([500,2500],[1120,1120])
plt.plot([500,2500],[1130,1130])
#plt.plot([500,500],[0,1200])
#plt.plot([700,700],[0,1200])

plt.imshow(img)
plt.show()
