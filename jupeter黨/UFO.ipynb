# %%
# %matplotlib inline

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
df=pd.read_csv("http://bit.ly/uforeports")
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df_state=df.groupby("State").count() #groupby以("")作為集合 count計算次數
df_state
將
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# AK      116               25              99   116
# AL      193               21             173   193
# AR      206               26             186   206
# AZ      736              145             644   738
# CA     2525              457            2148  2529
# CO      367               60             322   367
# CT      225               25             188   225
# Ca        1                0               1     1
# DE       43                5              38    43
# FL      835              120             727   837
# Fl        4                1               0     4
# GA      325               44             294   325
# HI       85               16              74    85
# IA      162               28             142   162
# ID      130               12             109   130
# IL      612              112             540   613
# IN      326               49             296   326
# ...

# %%
df_state.sort_values("Time",ascending=False將將
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# CA     2525              457            2148  2529
# WA     1320              269             925  1322
# TX     1025              138             923  1027
# NY      913              123             823   914
# FL      835              120             727   837
# AZ      736              145             644   738
# OH      665               93             605   667
# IL      612              112             540   613
# PA      598               97             519   598
# MI      590               78             504   591
# OR      534               89             414   534
# MO      448               86             386   448
# NJ      370               51             326   370
# CO      367               60             322   367
# WI      357               63             312   357
# NC      356               55             325   356
# IN      326               49             296   326
# ...

# %%
df_state.sort_values("Time",ascending=False,inplace=True) #inplace 將sort後的值取代原本
df_state.head(錢ㄥ)
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# CA     2525              457            2148  2529
# WA     1320              269             925  1322
# TX     1025              138             923  1027
# NY      913              123             823   914
# FL      835              120             727   837
# AZ      736              145             644   738
# OH      665               93             605   667
# IL      612              112             540   613
# PA      598               97             519   598
# MI      590               78             504   591

# %%
df_state[:10].Time.plot(kind="bar") #前10個 bar長條圖
# Out:
# <AxesSubplot:xlabel='State'>

# %%
df = pd.DataFrame(np.random.randn(5, 3),
                                index=list(range(1, 6)),
                                columns=list("ABC"))

# %%
df.head()
# Out:
#           A         B         C
# 1 -0.016546  1.149186 -0.051010
# 2 -0.205156 -0.424288  0.686539
# 3  1.287321 -0.026953  0.848759
# 4  0.872243  0.691063  0.413372
# 5  1.012769  0.077662 -1.445256

# %%
df.loc[df.B>0, "C"] = 0
df.head()
#把B>0的C值改為0
# Out:
#           A         B         C
# 1 -2.258407 -0.194651  1.735550
# 2 -0.605873  0.814950  0.000000
# 3  0.722029  0.194256  0.000000
# 4  0.052867 -0.445294 -0.615532
# 5  0.276877 -1.608766 -0.012420
